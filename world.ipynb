# %% [markdown]
# ## ASSIGNMENT ON FILTERING

# %%
import pandas as pd 
data = pd.read_csv(r"C:\Users\HP\Documents\world_suicide.csv")
data
# 1. checking the duplicates
duplicates = data.duplicated().sum()
duplicates
# 2. Missing values
missing = data.isna().sum()
missing
# 3. Nigeria highest year
nigeria = data[data["Country Name"]== "Nigeria"]
nigeria_highest_year = nigeria.loc[nigeria["Suicide Rate"].idxmax()]
nigeria_highest_year
# 4. Number of countries
country_count = data["Country Name"].nunique()
country_count
# 5. Country with highest suicide mortality
highest_mortality = data.loc[data["Suicide Rate"].idxmax()]
highest_mortality
# 6. Nigeria vs niger
nigeria_15 = nigeria[nigeria["Year"] == 2015]["Suicide Rate"]
nigeria_15
niger_15 = data[(data["Country Name"] == " Niger") & (data["Year"] == 2015)]["Suicide Rate"]
niger_15
# 7. Highest in covid
covid = data[data["Year"] == 2020]
covid_highest = covid.loc[covid["Suicide Rate"].idxmax()]
covid_highest
# 8. Highest mortality for each country
highest_mortality_country = data.groupby("Country Name")["Suicide Rate"].max()
highest_mortality_country
# 9. Coountries that recorded suicide mortality rates greater than 20
